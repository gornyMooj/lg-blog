# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
wiki_base_url = 'https://en.wikipedia.org'
wiki_page_url = '/wiki/List_of_Nobel_laureates_in_Literature'

# accessing the website
page = requests.get(f'{wiki_base_url}{wiki_page_url}')
soup = BeautifulSoup(page.content, 'html.parser')

# getting all tables from the website 
tables = soup.find_all("table")
print(f'Numebr of tables on the page:{len(tables)}')
# Out:
# Numebr of tables on the page:10

# %%
# We want to scrap the info from the first table
# we seclect it
table = tables[0]

# %%
# we get a list of the columns 
columns_names = [x.text for x in table.find_all("th")]
print(columns_names)
# Out:
# ['Year\n', 'Picture\n', 'Laureate\n', 'Country\n', 'Language(s)\n', 'Citation\n', 'Genre(s)\n']

# %%
# removing new lines from the string using .rstrip()  - method returns a right trim version of the string
columns_names = [x.rstrip() for x in columns_names]
print(columns_names)
# Out:
# ['Year', 'Picture', 'Laureate', 'Country', 'Language(s)', 'Citation', 'Genre(s)']

# %% [markdown]
# **Getting rows of the data**

# %%
raw_rows = table.find("tbody").find_all("tr")
print(' We remove the first item from the list containing the column names that we already have',raw_rows[0].find_all("th"))
# Out:
#  We remove the first item from the list containing the column names that we already have [<th>Year
# </th>, <th>Picture
# </th>, <th>Laureate
# </th>, <th>Country
# </th>, <th>Language(s)
# </th>, <th>Citation
# </th>, <th>Genre(s)
# </th>]

# %%
# removing the first item from the list
raw_rows = raw_rows[1:]

# %%
# in some years we do not have any laureates; we need to identify those rows and ignore them
# or in some years we have 2, not one laureate

data = []
for index_row, item in enumerate(raw_rows):
    row=[]
    line = item.find_all('td')
    if len(line) == 2: continue # when year without laureates do not add a line to data
    for index, td in enumerate(line):
        row.append((td.text).rstrip())
        if index == 2:
            link = td.a['href']   # getting a link to the wiki page from the 'Laureate' column
    if len(line) == 6:   # handling year information for years with 2 laureates
        row.insert(0, year)
        
    row.append(link) # adding link into a row
    
    year = row[0] # saving info about a year; this is used when we have years with 2 laureates
    data.append(row)

# %%
# prepering  datastructure for Pandas Dataframe
columns_names.append('Wiki_LINK')
data_for_df = {i:[] for i in columns_names}
print(data_for_df)
# Out:
# {'Year': [], 'Picture': [], 'Laureate': [], 'Country': [], 'Language(s)': [], 'Citation': [], 'Genre(s)': [], 'Wiki_LINK': []}

# %%
# moving data from the 2D list to a python dictionary

for row in data:
    for index in range(len(row)):
        data_for_df[columns_names[index]].append(row[index])

# %%
# creating dataframe from the dictionary
df = pd.DataFrame(data_for_df)
df.head(2)
# Out:
#    Year Picture                      Laureate   Country Language(s)  \
# 0  1901          Sully Prudhomme  (1839–1907)    France      French
# 1  1902          Theodor Mommsen  (1817–1903)   Germany      German
#
#                                             Citation       Genre(s)  \
# 0  "in special recognition of his poetic composit...  poetry, essay
# 1  "the greatest living master of the art of hist...   history, law
#
#                Wiki_LINK
# 0  /wiki/Sully_Prudhomme
# 1  /wiki/Theodor_Mommsen

# %%
# dumping the 'Picture' field
df = df.drop('Picture',axis=1)

# %%
df.head(30)
# Out:
#     Year                              Laureate  \
# 13  "because of his profoundly sensitive, fresh an...
# 14  "as a tribute to the lofty idealism of his lit...
# 15  "in recognition of his significance as the lea...
# 16  "for his varied and rich poetry, which is insp...
# 17  "for his authentic descriptions of present-day...
# 18  "in special appreciation of his epic, Olympian...
# 19  "for his monumental work, Growth of the Soil"[33]
# 20  "in recognition of his brilliant literary achi...
# 21  "for the happy manner in which he has continue...
# 22  "for his always inspired poetry, which in a hi...
# 23    "for his great national epic, The Peasants"[37]
# 24  "for his work which is marked by both idealism...
# 25  "for her idealistically inspired writings, whi...
# 26  "in recognition of his rich and vitalizing ide...
# 27  "principally for her powerful descriptions of ...
# 28  "principally for his great novel, Buddenbrooks...
# 29  "for his vigorous and graphic art of descripti...
#
#                                              Genre(s)  \
# 0                                       poetry, essay
# 1                                        history, law
# 2                                poetry, novel, drama
# 3                                   poetry, philology
# 4                                               drama
# 5                                               novel
# 6                                              poetry
# 7                          novel, short story, poetry
# 8                                          philosophy
# 9                                  novel, short story
# 10                  poetry, drama, novel, short story
# 11                               drama, poetry, essay
# 12                                       drama, novel
# 13  poetry, novel, drama, short story, playwright,...
# 14                                              novel
# 15                                      poetry, novel
# 16                                             poetry
# 17                                              novel
# 18                                             poetry
# 19                                              novel
# 20                                      novel, poetry
# 21                                              drama
# 22                                             poetry
# 23                                              novel
# 24                          drama, literary criticism
# 25                                      poetry, novel
# 26                                         philosophy
# 27                                              novel
# 28                          novel, short story, essay
# 29                          novel, short story, drama
#
#                                 Wiki_LINK
# 0                   /wiki/Sully_Prudhomme
# 1                   /wiki/Theodor_Mommsen
# 2   /wiki/Bj%C3%B8rnstjerne_Bj%C3%B8rnson
# 3        /wiki/Fr%C3%A9d%C3%A9ric_Mistral
# 4               /wiki/Restoration_(Spain)
# 5                /wiki/Henryk_Sienkiewicz
# 6              /wiki/Giosu%C3%A8_Carducci
# 7                   /wiki/Rudyard_Kipling
# 8           /wiki/Rudolf_Christoph_Eucken
# 9               /wiki/Selma_Lagerl%C3%B6f
# 10                       /wiki/Paul_Heyse
# 11              /wiki/Maurice_Maeterlinck
# 12                /wiki/Gerhart_Hauptmann
# 13              /wiki/Rabindranath_Tagore
# 14                   /wiki/Romain_Rolland
# 15            /wiki/Verner_von_Heidenstam
# 16            /wiki/Karl_Adolph_Gjellerup
# 17                          /wiki/Denmark
# 18                   /wiki/Carl_Spitteler
# 19                      /wiki/Knut_Hamsun
# 20                   /wiki/Anatole_France
# 21                /wiki/Jacinto_Benavente
# 22                      /wiki/W._B._Yeats
# 23      /wiki/W%C5%82adys%C5%82aw_Reymont
# 24              /wiki/George_Bernard_Shaw
# 25                   /wiki/Grazia_Deledda
# 26                    /wiki/Henri_Bergson
# 27                    /wiki/Sigrid_Undset
# 28                      /wiki/Thomas_Mann
# 29                   /wiki/Sinclair_Lewis

# %%
print(df.loc[40]['Citation'])
# Out:
# "for his inspired writings, which while growing in boldness and penetration, exemplify the classical humanitarian ideals and high qualities of style"[55]
